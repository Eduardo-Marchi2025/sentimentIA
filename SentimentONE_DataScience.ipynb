# %% [markdown]
# # Projeto 1 - Grupo 13: SentimentAPI — Análise de Sentimentos de Feedbacks

# %% [markdown]
# **Descrição do projeto**
#
# Criar uma API simples que recebe textos (comentários, avaliações ou tweets), aplica um modelo de Data Science para classificar o sentimento (Positivo / Neutro / Negativo ou binário Positivo / Negativo) e retorna o resultado em formato JSON, permitindo que aplicações consumam essa predição automaticamente.

# %% [markdown]
# **Entregáveis desejados (Data Science)**
#
# Notebook (Jupyter/Colab) contendo:
#
# Exploração e limpeza dos dados (EDA);
#
# Transformação dos textos em números com TF-IDF;
#
# Treinamento de modelo supervisionado (ex.: Logistic Regression, Naive Bayes);
#
# Métricas de desempenho (Acurácia, Precisão, Recall, F1-score);
#
# Serialização do modelo (joblib/pickle).

# %% [markdown]
# # ⛏️ Exploração e limpeza dos dados (EDA)

# %%
# Bibliotecas utilizadas
import pandas as pd
import kagglehub
import os

# %%
# Download automático do Dataset diretamente do Kaggle
url = kagglehub.dataset_download("vivekattri/indias-fast-delivery-agents-reviews-and-ratings")

print("Download:", url)
# Out:
# Using Colab cache for faster access to the 'indias-fast-delivery-agents-reviews-and-ratings' dataset.
# Download: /kaggle/input/indias-fast-delivery-agents-reviews-and-ratings

# %%
# Nome do arquivo
os.listdir(url)
# Out:
# ['Fast Delivery Agent Reviews.csv']

# %%
# Caminho do arquivo
file_name = 'Fast Delivery Agent Reviews.csv'
csv_url = os.path.join(url, file_name)
csv_url
# Out:
# '/root/.cache/kagglehub/datasets/vivekattri/indias-fast-delivery-agents-reviews-and-ratings/versions/1/Fast Delivery Agent Reviews.csv'

# %%
# Lendo o arquivo CSV
df = pd.read_csv(csv_url)
df.head()
# Out:
#   Agent Name  Rating                                        Review Text  \
# 0      Zepto     4.5  Purpose boy job cup decision girl now get job ...
# 1      Zepto     2.1  Prevent production able both the box school wa...
# 2    JioMart     4.5  Family station listen agreement more kitchen l...
# 3    JioMart     2.6  World north people area everything enter beyon...
# 4      Zepto     3.6  Hand way yourself tax whether sister anyone ef...
#
#    Delivery Time (min)   Location  Order Type Customer Feedback Type  \
# 0                   58      Delhi  Essentials                Neutral
# 1                   25    Lucknow     Grocery               Negative
# 2                   54  Ahmedabad  Essentials                Neutral
# 3                   22    Chennai  Essentials                Neutral
# 4                   34       Pune    Pharmacy               Positive
#
#   Price Range Discount Applied Product Availability  Customer Service Rating  \
# ...

# %%
# Quantidade de linhas x colunas
df.shape
# Out:
# (5000, 12)

# %%
# Verificando os tipos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Agent Name               5000 non-null   object
#  1   Rating                   5000 non-null   float64
#  2   Review Text              5000 non-null   object
#  3   Delivery Time (min)      5000 non-null   int64
#  4   Location                 5000 non-null   object
#  5   Order Type               5000 non-null   object
#  6   Customer Feedback Type   5000 non-null   object
#  7   Price Range              5000 non-null   object
#  8   Discount Applied         5000 non-null   object
#  9   Product Availability     5000 non-null   object
#  10  Customer Service Rating  5000 non-null   int64
#  11  Order Accuracy           5000 non-null   object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 468.9+ KB

# %%
# Novo DataFrame para análise de feedback com nota de satisfação e serviço
df_sentimento_analise = df[['Review Text', 'Rating', 'Customer Feedback Type', 'Customer Service Rating']].copy()
df_sentimento_analise.head()
# Out:
#                                          Review Text  Rating  \
# 0  Purpose boy job cup decision girl now get job ...     4.5
# 1  Prevent production able both the box school wa...     2.1
# 2  Family station listen agreement more kitchen l...     4.5
# 3  World north people area everything enter beyon...     2.6
# 4  Hand way yourself tax whether sister anyone ef...     3.6
#
#   Customer Feedback Type  Customer Service Rating
# 0                Neutral                        4
# 1               Negative                        2
# 2                Neutral                        3
# 3                Neutral                        1
# 4               Positive                        2

# %%
df_sentimento_analise.columns
# Out:
# Index(['Review Text', 'Rating', 'Customer Feedback Type',
#        'Customer Service Rating'],
#       dtype='object')

# %% [markdown]
# # ⚙️ Aplicação da Técnica TF-IDF (Term Frequency-Inverse Document Frequency)

# %% [markdown]
# # 🧠 Treinamento de modelo supervisionado

# %% [markdown]
# # 📈 Métricas de desempenho (Acurácia, Precisão, Recall, F1-score);

# %% [markdown]
# # 💻 Serialização do modelo (joblib/pickle).
